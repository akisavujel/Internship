# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e6ebd04a-1208-492a-8a41-d6045c00c165" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6ebd04a-1208-492a-8a41-d6045c00c165">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_excel("google (1) copy.xlsx")

# %%
duplicates = df.duplicated().sum()
print(duplicates)
# Out:
# 10

# %%
counts = df["OSrXXb"].value_counts()

print(counts)
# Out:
# OSrXXb
# Saifee Hospital           13
# Anytime Fitness            5
# Krunch Fitness             4
# Garware Club House         4
# Mafatlal Swimming Pool     3
#                           ..
# Rebellion Fitness          1
# Diamond Muscles Gym        1
# K3 OXYGEN GYM              1
# IQ Fitness                 1
# Willingdon Sports Club     1
# Name: count, Length: 72, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df = df.rename(columns={
    "OSrXXb": "Gym Name",
    "rllt__details": "Category",
    "yi40Hd": "Rating",
    "RDApEe": "Number of Reviews",
    "rllt__details 2": "Years In Business",
    "rllt__details 3": "Contact Number",
    "rllt__details 4": "Opening Hours",
    "rllt__details 5": "Closing Hour",
    "uDyWh": "Review Snippet",
    "uDyWh 2": "Extra",
    "yYlJEf href": "Website",
    "QuU3Wb": "Extra 2",
    "yYlJEf href 2": "Google Maps Link"
})
df.columns
# Out:
# Index(['Gym Name', 'Category', 'Rating', 'Number of Reviews',
#        'Years In Business', 'Contact Number', 'Opening Hours', 'Closing Hour',
#        'Review Snippet', 'Extra', 'Website', 'Extra 2', 'Google Maps Link'],
#       dtype='object')

# %%
df = df.drop(columns=["Extra", "Extra 2"])

# %%
df.columns
# Out:
# Index(['Gym Name', 'Category', 'Rating', 'Number of Reviews',
#        'Years In Business', 'Contact Number', 'Opening Hours', 'Closing Hour',
#        'Review Snippet', 'Website', 'Google Maps Link'],
#       dtype='object')

# %%
df = df.drop_duplicates(subset=["Gym Name"], keep="first")

# %%
counts = df["Gym Name"].value_counts()

print(counts)
# Out:
# Gym Name
# Waves Gym                                                                   1
# Plus Fitness 24/7 Mumbai Central                                            1
# Anytime Fitness                                                             1
# To The Core Fitness                                                         1
# Elite Fitness Hub                                                           1
#                                                                            ..
# QI Spine Clinic - Orthopedic and Physiotherapy Treatment in Marine Lines    1
# Sarvadnya fitness                                                           1
# K3 OXYGEN GYM                                                               1
# IQ Fitness                                                                  1
# Willingdon Sports Club                                                      1
# Name: count, Length: 72, dtype: int64

# %%
df.shape
# Out:
# (72, 11)

# %%
df.to_excel("Data_2.xlsx", index=False)
from google.colab import files

files.download("Data_2.xlsx")
